# %%
from sympy import *
from sympy.plotting import plot
init_printing()

# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

# %%
# Определить корни
# x = Symbol('x')
# y = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# solve(y, x)
x = symbols('x')
a = -12*x*x*x*x*sin(cos(x)) - 18*x*x*x + 5*x*x + 10*x - 30
ans = solve(a)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/l4/35gq26m92pn91lbjktf_jhs40000gn/T/ipykernel_18988/3842251871.py in <module>
#       5 x = symbols('x')
#       6 a = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# ----> 7 ans = solve(a)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1104     ###########################################################################
#    1105     if bare_f:
# -> 1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
#    1108         solution = _solve_system(f, symbols, **flags)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1718
#    1719     if result is False:
# -> 1720         raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1721
#    1722     if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [x, sin(cos(x))]
# No algorithms are implemented to solve equation -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
# Найти интервалы, на которых функция возрастает

# %%
# Найти интервалы, на которых функция убывает

# %%
# Построить график
plot(y)

# %%
# Вычислить вершину

# %%
# Определить промежутки, на котором f > 0

# %%
# Определить промежутки, на котором f < 0
